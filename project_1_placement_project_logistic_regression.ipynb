# %% [markdown]
# <a href="https://colab.research.google.com/github/PiyushAggarwal01/MACHINE-LEARNING-PROJECTS-/blob/main/project_1_placement_project_logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing the libraries
import numpy as np
import pandas as pd

# %%
# opening the placement data file
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df.iloc[:,1:]
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['iq'], c=df['placement'])

# %%
x= df.iloc[:, :2]
y =df.iloc[:,-1]

# %%
x
# Out:
#     Unnamed: 0  cgpa
# 0            0   6.8
# 1            1   5.9
# 2            2   5.3
# 3            3   7.4
# 4            4   5.8
# ..         ...   ...
# 95          95   4.3
# 96          96   4.4
# 97          97   6.7
# 98          98   6.3
# 99          99   6.2
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     Unnamed: 0  cgpa
# 99          99   6.2
# 92          92   5.2
# 76          76   4.9
# 14          14   6.1
# 0            0   6.8
# ..         ...   ...
# 43          43   6.8
# 22          22   4.9
# 72          72   7.3
# 15          15   5.1
# 40          40   4.9
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 83    1
# 30    1
# 56    0
# 24    0
# 16    0
# 23    0
# 2     0
# 27    1
# 28    0
# 13    1
# Name: placement, dtype: int64

# %%
x_test
# Out:
#     Unnamed: 0  cgpa
# 83          83   7.5
# 30          30   7.6
# 56          56   6.1
# 24          24   4.7
# 16          16   5.2
# 23          23   4.7
# 2            2   5.3
# 27          27   6.0
# 28          28   5.2
# 13          13   6.4

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.64777011,  0.16981077],
#        [ 1.40420015, -0.69853978],
#        [ 0.84746881, -0.95904494],
#        [-1.30986512,  0.08297572],
#        [-1.79700504,  0.6908211 ],
#        [-1.06629516,  0.95132627],
#        [-1.69261791,  1.21183143],
#        [-0.78792949,  0.86449121],
#        [ 0.32553319,  1.12499638],
#        [ 0.95185594,  0.43031594],
#        [-0.57915524,  0.6908211 ],
#        [-1.41425225,  0.77765616],
#        [ 1.12583448, -0.2643645 ],
#        [-0.26599386,  1.29866649],
#        [ 0.74308169, -0.95904494],
#        [-1.6230265 ,  0.95132627],
#        [-0.92711233, -0.87220989],
#        [ 0.88226452,  1.12499638],
#        [ 0.7778774 ,  0.60398605],
#        [ 0.36032889, -0.00385934],
#        [ 0.46471602,  1.81967682],
#        [-1.76220933, -0.09069439],
#        [-1.17068229, -1.74056044],
#        [-0.12681103,  0.51715099],
#        [-0.54435953, -0.2643645 ],
#        [ 0.91706023,  0.08297572],
#        [-1.58823079, -0.2643645 ],
# ...

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 1.09103877,  1.29866649],
#        [-0.75313378,  1.38550154],
#        [ 0.15155464,  0.08297572],
#        [-0.96190803, -1.13271505],
#        [-1.2402737 , -0.69853978],
#        [-0.99670374, -1.13271505],
#        [-1.72741362, -0.61170472],
#        [-0.85752091, -0.00385934],
#        [-0.8227252 , -0.69853978],
#        [-1.34466083,  0.34348088]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model Training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred= clf.predict(x_test)

# %%
y_test
# Out:
# 47    0
# 94    0
# 87    1
# 52    1
# 72    1
# 0     1
# 4     0
# 73    0
# 16    0
# 1     0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train.values, y_train.values, clf=clf, legend=2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
